# %% [markdown]
# # REVERSE LINKED LIST
#
# Given the head of a singly linked list, reverse the list, and return the reversed list.
#
#
# ### Example 1:
#
# ![rll.png](attachment:rll.png)
#
# Input: head = [1,2,3,4,5]
#
# Output: [5,4,3,2,1]
#
# ### Example 2:
#
# ![rll2.png](attachment:rll2.png)
#
# Input: head = [1,2]
#
# Output: [2,1]
#
# ### Example 3:
#
# Input: head = []
#
# Output: []
#
# ### Constraints:
#
# The number of nodes in the list is the range [0, 5000].
#
# -5000 <= Node.val <= 5000

# %% [markdown]
# ## Approach 1: Iterative

# %%
# head: ListNode
# return -> ListNode

# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

class Solution:
    def reverseList(self, head):
        
        while head.next:
            
            next_node = head.next
            next_node.next = head
            head = next_node
            
        while head.next:
            print(head.val)
        
        return head

# %%
Solution.reverseList(Solution.reverseList, ListNode([1,2]))

# %%
h = ListNode([1,2])

# %%
h

# %%
h.val
# Out:
# [1, 2]

# %%
h.next.next
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-1962fe4da02d> in <module>
# ----> 1 h.next.next
#
# AttributeError: 'NoneType' object has no attribute 'next'
